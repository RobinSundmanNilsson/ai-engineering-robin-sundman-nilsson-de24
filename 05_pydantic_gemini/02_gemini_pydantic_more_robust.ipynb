# %% [markdown]
# ## Structure Google Gemini outputs with Pydantic

# %%
from google import genai
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str 
    description: str
    ingredients: list[str]

client = genai.Client()

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
)

print(response.text)
# Out:
# Here are a few delightful Asian soup recipes, each with a yummy description and its key ingredients!
#
# ---
#
# ### 1. Tom Yum Goong (Thai Hot and Sour Shrimp Soup)
#
# **Yummy Description:**
# Get ready for an explosion of vibrant flavors that dance on your palate! Tom Yum Goong is a quintessential Thai masterpiece, boasting a harmonious balance of **spicy, sour, and aromatic** notes. Imagine a clear, fragrant broth infused with the bright zest of lemongrass, the warmth of galangal, and the citrusy perfume of kaffir lime leaves. Plump, succulent shrimp swim alongside earthy mushrooms and juicy cherry tomatoes, all brought together with a kick of fresh chilies and a hint of fish sauce. It's an invigorating and utterly addictive experience that's both comforting and electrifying.
#
# **Key Ingredients:**
# *   **Broth:** Chicken or vegetable broth
# *   **Aromatics:** Lemongrass stalks (bruised), galangal (sliced), kaffir lime leaves (torn), Thai bird's eye chilies (crushed or sliced)
# *   **Protein:** Fresh shrimp (peeled and deveined)
# *   **Vegetables:** Straw mushrooms or oyster mushrooms, cherry tomatoes
# *   **Seasoning:** Fish sauce, fresh lime juice
# *   **Garnish:** Fresh cilantro
#
# ---
#
# ### 2. Pho Bo (Vietnamese Beef Noodle Soup)
#
# **Yummy Description:**
# A truly soul-warming and deeply aromatic experience, Pho Bo is Vietnam's iconic beef noodle soup. It features a **fragrant, complex broth** that's been slow-simmered for hours with roasted spices and beef bones, resulting in a clear, golden liquid brimming with umami. Nestled within are silky-smooth flat rice noodles, paper-thin slices of tender raw beef that cook instantly in the hot broth, and sometimes luscious pieces of cooked brisket or flank. It's served with an essential platter of fresh herbs like Thai basil, cilantro, and mint, alongside crisp bean sprouts and a squeeze of lime, allowing you to customize each spoonful to perfection.
#
# **Key Ingredients:**
# *   **Broth:** Beef bones (knuckle, marrow), water
# *   **Aromatics (for broth):** Star anise, cinnamon sticks, black cardamom pods, cloves, coriander seeds, ginger (roasted), onion (roasted)
# *   **Seasoning (for broth):** Fish sauce, rock sugar or regular sugar
# *   **Noodles:** Flat rice noodles (bánh phở)
# *   **Beef:** Thinly sliced raw beef (e.g., eye round, sirloin), cooked beef (e.g., brisket, flank steak)
# *   **Garnishes:** Bean sprouts, lime wedges, fresh herbs (Thai basil, cilantro, mint), sliced jalapeños or bird's eye chilies, hoisin sauce, sriracha.
#
# ---
#
# ### 3. Miso Soup (Japanese Miso Soup)
#
# **Yummy Description:**
# Miso soup is the ultimate comforting embrace, a delicate yet deeply savory staple of Japanese cuisine that warms you from the inside out. It's built upon a foundation of **umami-rich dashi broth**, gently whisked with a flavorful miso paste that offers a delightful salinity and depth. Slippery cubes of silken tofu, wisps of rehydrated wakame seaweed, and thinly sliced green onions complete this simple masterpiece. Each spoonful is a harmonious balance of textures and subtle flavors, making it the perfect restorative starter or light meal.
#
# **Key Ingredients:**
# *   **Broth:** Dashi (made from kombu seaweed and bonito flakes, or dashi powder)
# *   **Main Flavor:** Miso paste (white/shiro miso for lighter flavor, red/aka miso for stronger, or a blend)
# *   **Add-ins:** Silken or firm tofu (cut into small cubes), dried wakame seaweed (rehydrated)
# *   **Garnish:** Thinly sliced green onions
#
# ---
#
# ### 4. Hot and Sour Soup (Chinese Hot and Sour Soup)
#
# **Yummy Description:**
# Prepare for a bold and invigorating dance of flavors with this classic Chinese Hot and Sour Soup! It's a tantalizing symphony of **tangy sourness from black vinegar and a subtle, warming heat from white pepper and chili oil**, all swirled into a satisfyingly thick, savory broth. You'll discover a delightful array of textures from earthy rehydrated shiitake mushrooms, slippery wood ear mushrooms, crunchy bamboo shoots, and tender shredded pork (or tofu for a vegetarian version). Finally, delicate, silken strands of egg ribbon through the broth, adding a luxurious finish. It's a hearty, flavorful, and wonderfully comforting soup that truly wakes up the palate.
#
# **Key Ingredients:**
# *   **Broth:** Chicken or vegetable broth
# *   **Protein:** Shredded pork, chicken, or firm tofu
# *   **Mushrooms:** Dried shiitake mushrooms (rehydrated and sliced), dried wood ear mushrooms (rehydrated and sliced)
# *   **Vegetables:** Bamboo shoots (julienned)
# *   **Flavor/Heat/Sour:** Black vinegar, soy sauce, white pepper, sesame oil, chili oil (optional)
# *   **Thickener:** Cornstarch slurry
# *   **Finishers:** Egg (beaten), green onions (for garnish)
#
# ---

# %%
response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
    config = {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [{"recipe_name":"Classic Miso Soup","description":"A comforting and savory Japanese staple, this light yet flavorful soup features delicate tofu, seaweed, and a fragrant miso broth that warms you from the inside out.","ingredients":["Dashi stock","Miso paste","Silken tofu","Wakame seaweed","Green onions"]},{"recipe_name":"Spicy Tom Yum Goong","description":"A vibrant and aromatic Thai hot and sour soup, bursting with the flavors of lemongrass, galangal, kaffir lime leaves, and juicy shrimp. It's an exhilarating explosion of spicy, sour, and savory notes.","ingredients":["Shrimp","Lemongrass","Galangal","Kaffir lime leaves","Fish sauce","Lime juice","Chili paste (Nam Prik Pao)","Mushrooms","Cherry tomatoes","Cilantro"]},{"recipe_name":"Vietnamese Pho Bo (Beef Noodle Soup)","description":"A deeply aromatic and incredibly satisfying Vietnamese beef noodle soup, renowned for its rich, complex broth simmered with star anise, cinnamon, and ginger, served with tender slices of beef, rice noodles, and fresh herbs.","ingredients":["Beef bones","Beef chuck or brisket","Rice noodles","Onions","Ginger","Star anise","Cinnamon sticks","Cloves","Fish sauce","Sugar","Bean sprouts","Thai basil","Cilantro","Lime wedges","Jalapeño slices"]}]

# %%
recipes = response.parsed
recipes
# Out:
# [Recipe(recipe_name='Classic Miso Soup', description='A comforting and savory Japanese staple, this light yet flavorful soup features delicate tofu, seaweed, and a fragrant miso broth that warms you from the inside out.', ingredients=['Dashi stock', 'Miso paste', 'Silken tofu', 'Wakame seaweed', 'Green onions']),
#  Recipe(recipe_name='Spicy Tom Yum Goong', description="A vibrant and aromatic Thai hot and sour soup, bursting with the flavors of lemongrass, galangal, kaffir lime leaves, and juicy shrimp. It's an exhilarating explosion of spicy, sour, and savory notes.", ingredients=['Shrimp', 'Lemongrass', 'Galangal', 'Kaffir lime leaves', 'Fish sauce', 'Lime juice', 'Chili paste (Nam Prik Pao)', 'Mushrooms', 'Cherry tomatoes', 'Cilantro']),
#  Recipe(recipe_name='Vietnamese Pho Bo (Beef Noodle Soup)', description='A deeply aromatic and incredibly satisfying Vietnamese beef noodle soup, renowned for its rich, complex broth simmered with star anise, cinnamon, and ginger, served with tender slices of beef, rice noodles, and fresh herbs.', ingredients=['Beef bones', 'Beef chuck or brisket', 'Rice noodles', 'Onions', 'Ginger', 'Star anise', 'Cinnamon sticks', 'Cloves', 'Fish sauce', 'Sugar', 'Bean sprouts', 'Thai basil', 'Cilantro', 'Lime wedges', 'Jalapeño slices'])]

# %%
recipes[0].description, recipes[0].recipe_name, recipes[0].ingredients
# Out:
# ('A comforting and savory Japanese staple, this light yet flavorful soup features delicate tofu, seaweed, and a fragrant miso broth that warms you from the inside out.',
#  'Classic Miso Soup',
#  ['Dashi stock',
#   'Miso paste',
#   'Silken tofu',
#   'Wakame seaweed',
#   'Green onions'])

# %% [markdown]
# ## Simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int 
    monthly_fee: int
    living_area: float 
    number_rooms: int 
    type: Literal["apartment", "house"]
    address: str 



response = client.models.generate_content(
    model = "gemini-2.5-pro",
    contents = """List 50 apartments and houses in Sweden with their monthly_fee, their price, living area, 
    number of rooms, address, type if it is apartment or house. 
    All currencies are in SEK.""",
    config = {"response_mime_type": "application/json", "response_schema": list[Home]}
)


homes = response.parsed
homes
# Out:
# [Home(price=5250000, monthly_fee=3150, living_area=65.5, number_rooms=2, type='apartment', address='Hornsgatan 72, 118 21 Stockholm'),
#  Home(price=9800000, monthly_fee=4500, living_area=180.0, number_rooms=6, type='house', address='Långedragsvägen 55, 426 71 Västra Frölunda'),
#  Home(price=3150000, monthly_fee=4200, living_area=82.0, number_rooms=3, type='apartment', address='Sundspromenaden 19, 211 16 Malmö'),
#  Home(price=6500000, monthly_fee=3800, living_area=160.0, number_rooms=5, type='house', address='Nåntunavägen 112, 757 52 Uppsala'),
#  Home(price=2400000, monthly_fee=3500, living_area=75.0, number_rooms=3, type='apartment', address='Klostergatan 30, 582 23 Linköping'),
#  Home(price=6800000, monthly_fee=4100, living_area=88.0, number_rooms=4, type='apartment', address='Odengatan 45, 113 51 Stockholm'),
#  Home(price=8200000, monthly_fee=4900, living_area=195.0, number_rooms=7, type='house', address='Strandgatan 88, 216 12 Limhamn'),
#  Home(price=3900000, monthly_fee=2900, living_area=58.5, number_rooms=2, type='apartment', address='Karl Johansgatan 15, 414 59 Göteborg'),
#  Home(price=4300000, monthly_fee=3200, living_area=140.0, number_rooms=5, type='house', address='Tegsvägen 21, 904 33 Umeå'),
#  Home(price=3500000, monthly_fee=3800, living_area=69.0, number_rooms=2, type='apartment', address='Stora Södergatan 12, 222 23 Lund'),
#  Home(price=11500000, monthly_fee=5500, living_area=210.0, number_rooms=8, type='house', address='Ålstensgatan 14, 167 65 Bromma'),
#  Home(price=1800000, monthly_fee=4100, living_area=92.0, number_rooms=4, type='apartment', address='Drottninggatan 50, 602 32 Norrköping'),
#  Home(price=3200000, monthly_fee=2800, living_area=125.0, number_rooms=4, type='house', address='Bjurhovdagatan 9, 724 70 Västerås'),
#  Home(price=1650000, monthly_fee=3300, living_area=68.0, number_rooms=3, type='apartment', address='Järntorgsgatan 5, 703 61 Örebro'),
#  Home(price=7900000, monthly_fee=4700, living_area=175.0, number_rooms=6, type='house', address='Tågagatan 33, 254 39 Helsingborg'),
#  Home(price=2100000, monthly_fee=2950, living_area=55.0, number_rooms=2, type='apartment', address='Klostergatan 22, 553 17 Jönköping'),
#  Home(price=4500000, monthly_fee=2800, living_area=45.0, number_rooms=1, type='apartment', address='Hantverkargatan 34, 112 21 Stockholm'),
#  Home(price=4800000, monthly_fee=3600, living_area=155.0, number_rooms=5, type='house', address='Sommarrovägen 18, 653 46 Karlstad'),
#  Home(price=1200000, monthly_fee=3900, living_area=85.0, number_rooms=3, type='apartment', address='Södra Kungsgatan 10, 802 51 Gävle'),
#  Home(price=3500000, monthly_fee=3100, living_area=130.0, number_rooms=4, type='house', address='Brämhultsvägen 67, 507 31 Brämhult'),
#  Home(price=4100000, monthly_fee=4800, living_area=105.0, number_rooms=4, type='apartment', address='Kungsgatan 21, 211 49 Malmö'),
#  Home(price=3800000, monthly_fee=3400, living_area=145.0, number_rooms=5, type='house', address='Mjölkuddsvägen 150, 973 41 Luleå'),
#  Home(price=2800000, monthly_fee=3600, living_area=72.0, number_rooms=3, type='apartment', address='Virvelvindsgatan 8, 417 02 Göteborg'),
#  Home(price=5900000, monthly_fee=4200, living_area=165.0, number_rooms=6, type='house', address='Ekängsvägen 4, 582 52 Linköping'),
#  Home(price=2950000, monthly_fee=3100, living_area=60.0, number_rooms=2, type='apartment', address='Vaksalagatan 58, 753 31 Uppsala'),
#  Home(price=4100000, monthly_fee=3300, living_area=135.0, number_rooms=5, type='house', address='Lovisagatan 11, 554 62 Jönköping'),
#  Home(price=6200000, monthly_fee=4500, living_area=80.0, number_rooms=3, type='apartment', address='Hammarby Allé 90, 120 64 Stockholm'),
#  Home(price=4500000, monthly_fee=3700, living_area=150.0, number_rooms=5, type='house', address='Adolfsbergsvägen 32, 702 26 Örebro'),
#  Home(price=2500000, monthly_fee=3700, living_area=78.0, number_rooms=3, type='apartment', address='Bergaliden 17, 252 23 Helsingborg'),
#  Home(price=3900000, monthly_fee=3500, living_area=140.0, number_rooms=5, type='house', address='Hovsvägen 5, 352 40 Växjö'),
#  Home(price=1900000, monthly_fee=3200, living_area=62.0, number_rooms=2, type='apartment', address='Hagaplan 6, 903 28 Umeå'),
#  Home(price=5200000, monthly_fee=4000, living_area=160.0, number_rooms=6, type='house', address='Lindövägen 81, 603 65 Norrköping'),
#  Home(price=1800000, monthly_fee=2800, living_area=50.0, number_rooms=2, type='apartment', address='Fäladstorget 3, 226 47 Lund'),
#  Home(price=14500000, monthly_fee=6500, living_area=250.0, number_rooms=8, type='house', address='Skärsätravägen 12, 181 64 Lidingö'),
#  Home(price=5500000, monthly_fee=3400, living_area=75.0, number_rooms=3, type='apartment', address='Linnégatan 29, 413 04 Göteborg'),
#  Home(price=4800000, monthly_fee=3900, living_area=155.0, number_rooms=5, type='house', address='Klågerupsvägen 200, 212 32 Malmö'),
#  Home(price=2200000, monthly_fee=4300, living_area=88.0, number_rooms=4, type='apartment', address='Stora Gatan 41, 722 12 Västerås'),
#  Home(price=3600000, monthly_fee=3000, living_area=120.0, number_rooms=4, type='house', address='Råtorpsvägen 14, 653 49 Karlstad'),
#  Home(price=8900000, monthly_fee=5200, living_area=95.0, number_rooms=3, type='apartment', address='Karlavägen 70, 114 59 Stockholm'),
#  Home(price=7200000, monthly_fee=4600, living_area=185.0, number_rooms=6, type='house', address='Sunnerstavägen 35, 756 51 Uppsala'),
#  Home(price=3800000, monthly_fee=4100, living_area=85.0, number_rooms=3, type='apartment', address='Limhamnsvägen 25, 217 59 Malmö'),
#  Home(price=8500000, monthly_fee=5100, living_area=190.0, number_rooms=7, type='house', address='Askims Sörgårdsväg 10, 436 43 Askim'),
#  Home(price=1750000, monthly_fee=3000, living_area=58.0, number_rooms=2, type='apartment', address='Nya Tanneforsvägen 60, 582 42 Linköping'),
#  Home(price=5500000, monthly_fee=4100, living_area=170.0, number_rooms=6, type='house', address='Villagatan 1, 802 52 Gävle'),
#  Home(price=2900000, monthly_fee=3800, living_area=80.0, number_rooms=3, type='apartment', address='Barnarpsgatan 90, 553 32 Jönköping'),
#  Home(price=5300000, monthly_fee=4200, living_area=160.0, number_rooms=5, type='house', address='Bäckagårdsvägen 2, 302 40 Halmstad'),
#  Home(price=2300000, monthly_fee=4500, living_area=95.0, number_rooms=4, type='apartment', address='Sturegatan 15, 503 36 Borås'),
#  Home(price=3100000, monthly_fee=2900, living_area=130.0, number_rooms=4, type='house', address='Rosenforsvägen 8, 633 55 Eskilstuna'),
#  Home(price=2000000, monthly_fee=3900, living_area=75.0, number_rooms=3, type='apartment', address='Storgatan 10, 151 72 Södertälje'),
#  Home(price=10500000, monthly_fee=5300, living_area=200.0, number_rooms=7, type='house', address='Viggbyholmsvägen 40, 183 57 Täby')]

# %%
len(homes)
# Out:
# 50

# %%
import pandas as pd

df = pd.DataFrame([home.__dict__ for home in homes])
df.head()
# Out:
#      price  monthly_fee  living_area  number_rooms       type  \
# 0  5250000         3150         65.5             2  apartment
# 1  9800000         4500        180.0             6      house
# 2  3150000         4200         82.0             3  apartment
# 3  6500000         3800        160.0             5      house
# 4  2400000         3500         75.0             3  apartment
#
#                                       address
# 0             Hornsgatan 72, 118 21 Stockholm
# 1  Långedragsvägen 55, 426 71 Västra Frölunda
# 2            Sundspromenaden 19, 211 16 Malmö
# 3            Nåntunavägen 112, 757 52 Uppsala
# 4           Klostergatan 30, 582 23 Linköping

# %%
df.query("price < 3_000_000")
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 4   2400000         3500         75.0             3  apartment
# 11  1800000         4100         92.0             4  apartment
# 13  1650000         3300         68.0             3  apartment
# 15  2100000         2950         55.0             2  apartment
# 18  1200000         3900         85.0             3  apartment
# 22  2800000         3600         72.0             3  apartment
# 24  2950000         3100         60.0             2  apartment
# 28  2500000         3700         78.0             3  apartment
# 30  1900000         3200         62.0             2  apartment
# 32  1800000         2800         50.0             2  apartment
# 36  2200000         4300         88.0             4  apartment
# 42  1750000         3000         58.0             2  apartment
# 44  2900000         3800         80.0             3  apartment
# 46  2300000         4500         95.0             4  apartment
# 48  2000000         3900         75.0             3  apartment
#
#                                     address
# 4         Klostergatan 30, 582 23 Linköping
# 11     Drottninggatan 50, 602 32 Norrköping
# 13          Järntorgsgatan 5, 703 61 Örebro
# 15        Klostergatan 22, 553 17 Jönköping
# 18        Södra Kungsgatan 10, 802 51 Gävle
# 22      Virvelvindsgatan 8, 417 02 Göteborg
# 24          Vaksalagatan 58, 753 31 Uppsala
# 28        Bergaliden 17, 252 23 Helsingborg
# 30                  Hagaplan 6, 903 28 Umeå
# 32              Fäladstorget 3, 226 47 Lund
# 36          Stora Gatan 41, 722 12 Västerås
# 42  Nya Tanneforsvägen 60, 582 42 Linköping
# 44       Barnarpsgatan 90, 553 32 Jönköping
# 46              Sturegatan 15, 503 36 Borås
# 48          Storgatan 10, 151 72 Södertälje

# %%
cheap_houses = df.query("price < 5_000_000 and type == 'house'")
cheap_houses
# Out:
#       price  monthly_fee  living_area  number_rooms   type  \
# 8   4300000         3200        140.0             5  house
# 12  3200000         2800        125.0             4  house
# 17  4800000         3600        155.0             5  house
# 19  3500000         3100        130.0             4  house
# 21  3800000         3400        145.0             5  house
# 25  4100000         3300        135.0             5  house
# 27  4500000         3700        150.0             5  house
# 29  3900000         3500        140.0             5  house
# 35  4800000         3900        155.0             5  house
# 37  3600000         3000        120.0             4  house
# 47  3100000         2900        130.0             4  house
#
#                                 address
# 8             Tegsvägen 21, 904 33 Umeå
# 12    Bjurhovdagatan 9, 724 70 Västerås
# 17    Sommarrovägen 18, 653 46 Karlstad
# 19   Brämhultsvägen 67, 507 31 Brämhult
# 21     Mjölkuddsvägen 150, 973 41 Luleå
# 25     Lovisagatan 11, 554 62 Jönköping
# 27   Adolfsbergsvägen 32, 702 26 Örebro
# 29            Hovsvägen 5, 352 40 Växjö
# 35     Klågerupsvägen 200, 212 32 Malmö
# 37     Råtorpsvägen 14, 653 49 Karlstad
# 47  Rosenforsvägen 8, 633 55 Eskilstuna

# %%
cheap_houses.to_csv("cheap_houses.csv", index=False)
